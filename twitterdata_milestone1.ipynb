# %%
import pandas as pd

# %%
tweets = pd.read_csv('../Twitter Capstone Project/AirlineData.csv')
tweets.columns = ['user_number', 'user', 'tweet']
tweets
# Out:
#      user_number             user  \
# 0              0        payoung28
# 1              1     healthy_wrld
# 2              2      MattJBadley
# 3              3          _catte_
# 4              4     compareatrip
# 5              5   aviationsource
# 6              6   TuEventoUnico_
# 7              7         TreyMays
# 8              8      AlexCena_TX
# 9              9      SecGemsCast
# 10            10   NY_24telegraph
# 11            11      TravelPulse
# 12            12   Maggiemayehaha
# 13            13    TravisZerphey
# 14            14       LAPolitico
# 15            15        payoung28
# 16            16    TravisZerphey
# 17            17       lbaker1313
# 18            18     zeke_bierman
# 19            19          MrFW3__
# 20            20     compareatrip
# 21            21           htbmia
# 22            22   obsoletemiddle
# 23            23     CaptainTimAA
# 24            24       domportwoo
# 25            25   MeghannDermott
# ...
